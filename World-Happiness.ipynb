# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
first = pd.read_csv("2015.csv")
second = pd.read_csv("2016.csv")
third = pd.read_csv("2017.csv")
fourth = pd.read_csv("2018.csv")
fifth = pd.read_csv("2019.csv")

# %%
print(first.columns)
print(second.columns)
print(third.columns)
print(fourth.columns)
print(fifth.columns)
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
# ...

# %%
third.rename(columns = {"Happiness.Rank":"Happiness Rank", 
                        "Happiness.Score":"Happiness Score", 
                        "Economy..GDP.per.Capita.":"Economy (GDP per Capita)",
                       "Health..Life.Expectancy.":"Health (Life Expectancy)",
                       "Trust..Government.Corruption.":"Trust (Government Corruption)",
                       "Dystopia.Residual":"Dystopia Residual"},
             inplace = True)

# %%
fourth.rename(columns = {"Overall rank":"Happiness Rank",
                        "Country or region":"Country",
                        "Score":"Happiness Score",
                        "GDP per capita":"Economy (GDP per Capita)",
                        "Healthy life expectancy":"Health (Life Expectancy)",
                        "Freedom to make life choices":"Freedom",
                        "Perceptions of corruption":"Trust (Government Corruption)",
                        "Social support":"Family"},
              inplace = True)

# %%
fifth.rename(columns = {"Overall rank":"Happiness Rank",
                        "Country or region":"Country",
                        "Score":"Happiness Score",
                        "GDP per capita":"Economy (GDP per Capita)",
                        "Healthy life expectancy":"Health (Life Expectancy)",
                        "Freedom to make life choices":"Freedom",
                        "Perceptions of corruption":"Trust (Government Corruption)",
                        "Social support":"Family"},
              inplace = True)

# %%
first.drop(columns=["Standard Error", "Dystopia Residual"], inplace=True)

# %%
second.drop(columns=["Lower Confidence Interval", "Upper Confidence Interval", "Dystopia Residual"], inplace=True)

# %%
third.drop(columns=["Whisker.high", "Whisker.low", "Dystopia Residual"], inplace=True)

# %%
fifth["Region"] = "N/A"

# %%
columns = ["Happiness Rank", "Country", "Region", "Happiness Score", "Economy (GDP per Capita)", "Family", 
           "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)"]

first = first.reindex(columns=columns)
second = second.reindex(columns=columns)
third = third.reindex(columns=columns)
fourth = fourth.reindex(columns=columns)
fifth = fifth.reindex(columns=columns)

# %%
first.head(10)
# Out:
#    Happiness Rank      Country                     Region  Happiness Score  \
# 0               1  Switzerland             Western Europe            7.587
# 1               2      Iceland             Western Europe            7.561
# 2               3      Denmark             Western Europe            7.527
# 3               4       Norway             Western Europe            7.522
# 4               5       Canada              North America            7.427
# 5               6      Finland             Western Europe            7.406
# 6               7  Netherlands             Western Europe            7.378
# 7               8       Sweden             Western Europe            7.364
# 8               9  New Zealand  Australia and New Zealand            7.286
# 9              10    Australia  Australia and New Zealand            7.284
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
second.head(10)
# Out:
#    Happiness Rank      Country                     Region  Happiness Score  \
# 0               1      Denmark             Western Europe            7.526
# 1               2  Switzerland             Western Europe            7.509
# 2               3      Iceland             Western Europe            7.501
# 3               4       Norway             Western Europe            7.498
# 4               5      Finland             Western Europe            7.413
# 5               6       Canada              North America            7.404
# 6               7  Netherlands             Western Europe            7.339
# 7               8  New Zealand  Australia and New Zealand            7.334
# 8               9    Australia  Australia and New Zealand            7.313
# 9              10       Sweden             Western Europe            7.291
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
third.head(10)
# Out:
#    Happiness Rank      Country  Region  Happiness Score  \
# 0               1       Norway     NaN            7.537
# 1               2      Denmark     NaN            7.522
# 2               3      Iceland     NaN            7.504
# 3               4  Switzerland     NaN            7.494
# 4               5      Finland     NaN            7.469
# 5               6  Netherlands     NaN            7.377
# 6               7       Canada     NaN            7.316
# 7               8  New Zealand     NaN            7.314
# 8               9       Sweden     NaN            7.284
# 9              10    Australia     NaN            7.284
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# ...

# %%
fourth.head(10)
# Out:
#    Happiness Rank      Country  Region  Happiness Score  \
# 0               1      Finland     NaN            7.632
# 1               2       Norway     NaN            7.594
# 2               3      Denmark     NaN            7.555
# 3               4      Iceland     NaN            7.495
# 4               5  Switzerland     NaN            7.487
# 5               6  Netherlands     NaN            7.441
# 6               7       Canada     NaN            7.328
# 7               8  New Zealand     NaN            7.324
# 8               9       Sweden     NaN            7.314
# 9              10    Australia     NaN            7.272
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                     1.305   1.592                     0.874    0.681
# 1                     1.456   1.582                     0.861    0.686
# 2                     1.351   1.590                     0.868    0.683
# ...

# %%
fifth.head(10)
# Out:
#    Happiness Rank      Country Region  Happiness Score  \
# 0               1      Finland    N/A            7.769
# 1               2      Denmark    N/A            7.600
# 2               3       Norway    N/A            7.554
# 3               4      Iceland    N/A            7.494
# 4               5  Netherlands    N/A            7.488
# 5               6  Switzerland    N/A            7.480
# 6               7       Sweden    N/A            7.343
# 7               8  New Zealand    N/A            7.307
# 8               9       Canada    N/A            7.278
# 9              10      Austria    N/A            7.246
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                     1.340   1.587                     0.986    0.596
# 1                     1.383   1.573                     0.996    0.592
# 2                     1.488   1.582                     1.028    0.603
# 3                     1.380   1.624                     1.026    0.591
# ...

# %%
first[first["Country"].isin(second["Country"]) == False]
# Out:
#      Happiness Rank                   Country  \
# 21               22                      Oman
# 90               91         Somaliland region
# 93               94                Mozambique
# 96               97                   Lesotho
# 100             101                 Swaziland
# 125             126                  Djibouti
# 147             148  Central African Republic
#
#                               Region  Happiness Score  \
# 21   Middle East and Northern Africa            6.853
# 90                Sub-Saharan Africa            5.057
# 93                Sub-Saharan Africa            4.971
# 96                Sub-Saharan Africa            4.898
# 100               Sub-Saharan Africa            4.867
# 125               Sub-Saharan Africa            4.369
# 147               Sub-Saharan Africa            3.678
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 21                    1.36011  1.08182                   0.76276  0.63274
# ...

# %%
second[second["Country"].isin(first["Country"]) == False]
# Out:
#      Happiness Rank            Country                       Region  \
# 14               15        Puerto Rico  Latin America and Caribbean
# 51               52             Belize  Latin America and Caribbean
# 75               76            Somalia           Sub-Saharan Africa
# 96               97  Somaliland Region           Sub-Saharan Africa
# 112             113            Namibia           Sub-Saharan Africa
# 142             143        South Sudan           Sub-Saharan Africa
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 14             7.039                   1.35943  1.08113
# 51             5.956                   0.87616  0.68655
# 75             5.440                   0.00000  0.33613
# 96             5.057                   0.25558  0.75862
# 112            4.574                   0.93287  0.70362
# 142            3.832                   0.39394  0.18519
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)
# ...

# %%
first.loc[first["Country"]=="Somaliland region", "Country"] = "Somaliland Region"

# %%
first[first["Country"].isin(third["Country"]) == False]
# Out:
#      Happiness Rank            Country                           Region  \
# 21               22               Oman  Middle East and Northern Africa
# 37               38             Taiwan                     Eastern Asia
# 39               40           Suriname      Latin America and Caribbean
# 71               72          Hong Kong                     Eastern Asia
# 90               91  Somaliland Region               Sub-Saharan Africa
# 98               99               Laos                Southeastern Asia
# 100             101          Swaziland               Sub-Saharan Africa
# 125             126           Djibouti               Sub-Saharan Africa
# 139             140            Comoros               Sub-Saharan Africa
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 21             6.853                   1.36011  1.08182
# 37             6.298                   1.29098  1.07617
# 39             6.269                   0.99534  0.97200
# ...

# %%
third[third["Country"].isin(first["Country"]) == False]
# Out:
#      Happiness Rank                   Country  Region  Happiness Score  \
# 32               33  Taiwan Province of China     NaN            6.422
# 49               50                    Belize     NaN            5.956
# 70               71   Hong Kong S.A.R., China     NaN            5.472
# 92               93                   Somalia     NaN            5.151
# 110             111                   Namibia     NaN            4.574
# 146             147               South Sudan     NaN            3.591
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 32                   1.433627  1.384565                  0.793984  0.361467
# 49                   0.907975  1.081418                  0.450192  0.547509
# 70                   1.551675  1.262791                  0.943062  0.490969
# 92                   0.022643  0.721151                  0.113989  0.602127
# 110                  0.964434  1.098471                  0.338612  0.520304
# ...

# %%
third.loc[third["Country"]=="Taiwan Province of China", "Country"] = "Taiwan"
third.loc[third["Country"]=="Hong Kong S.A.R., China", "Country"] = "Hong Kong"
third.loc[third["Country"]=="Hong Kong"]
# Out:
#     Happiness Rank    Country  Region  Happiness Score  \
# 70              71  Hong Kong     NaN            5.472
#
#     Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 70                  1.551675  1.262791                  0.943062  0.490969
#
#     Trust (Government Corruption)
# 70                       0.293934

# %%
first[first["Country"].isin(fourth["Country"]) == False]
# Out:
#      Happiness Rank              Country                           Region  \
# 21               22                 Oman  Middle East and Northern Africa
# 39               40             Suriname      Latin America and Caribbean
# 40               41  Trinidad and Tobago      Latin America and Caribbean
# 65               66         North Cyprus                   Western Europe
# 90               91    Somaliland Region               Sub-Saharan Africa
# 100             101            Swaziland               Sub-Saharan Africa
# 125             126             Djibouti               Sub-Saharan Africa
# 139             140              Comoros               Sub-Saharan Africa
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 21             6.853                   1.36011  1.08182
# 39             6.269                   0.99534  0.97200
# 40             6.168                   1.21183  1.18354
# 65             5.695                   1.20806  1.07008
# ...

# %%
fourth[fourth["Country"].isin(first["Country"]) == False]
# Out:
#      Happiness Rank            Country  Region  Happiness Score  \
# 37               38  Trinidad & Tobago     NaN            6.192
# 48               49             Belize     NaN            5.956
# 57               58    Northern Cyprus     NaN            5.835
# 97               98            Somalia     NaN            4.982
# 118             119            Namibia     NaN            4.441
# 153             154        South Sudan     NaN            3.254
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 37                      1.223   1.492                     0.564    0.575
# 48                      0.807   1.101                     0.474    0.593
# 57                      1.229   1.211                     0.909    0.495
# 97                      0.000   0.712                     0.115    0.674
# 118                     0.874   1.281                     0.365    0.519
# 153                     0.337   0.608                     0.177    0.112
#
# ...

# %%
fourth.loc[fourth["Country"]=="Northern Cyprus", "Country"] = "North Cyprus"
fourth.loc[fourth["Country"]=="Trinidad & Tobago", "Country"] = "Trinidad and Tobago"

# %%
first[first["Country"].isin(fifth["Country"]) == False]
# Out:
#      Happiness Rank              Country                           Region  \
# 21               22                 Oman  Middle East and Northern Africa
# 39               40             Suriname      Latin America and Caribbean
# 40               41  Trinidad and Tobago      Latin America and Caribbean
# 65               66         North Cyprus                   Western Europe
# 90               91    Somaliland Region               Sub-Saharan Africa
# 92               93            Macedonia       Central and Eastern Europe
# 117             118                Sudan               Sub-Saharan Africa
# 125             126             Djibouti               Sub-Saharan Africa
# 136             137               Angola               Sub-Saharan Africa
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 21             6.853                   1.36011  1.08182
# 39             6.269                   0.99534  0.97200
# 40             6.168                   1.21183  1.18354
# ...

# %%
fifth[fifth["Country"].isin(first["Country"]) == False]
# Out:
#      Happiness Rank            Country Region  Happiness Score  \
# 38               39  Trinidad & Tobago    N/A            6.192
# 63               64    Northern Cyprus    N/A            5.718
# 83               84    North Macedonia    N/A            5.274
# 111             112            Somalia    N/A            4.668
# 112             113            Namibia    N/A            4.639
# 119             120             Gambia    N/A            4.516
# 155             156        South Sudan    N/A            2.853
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 38                      1.231   1.477                     0.713    0.489
# 63                      1.263   1.252                     1.042    0.417
# 83                      0.983   1.294                     0.838    0.345
# 111                     0.000   0.698                     0.268    0.559
# 112                     0.879   1.313                     0.477    0.401
# ...

# %%
first.loc[first["Country"]=="Macedonia", "Country"] = "North Macedonia"
fifth.loc[fifth["Country"]=="Northern Cyprus", "Country"] = "North Cyprus"
fifth.loc[fifth["Country"]=="Trinidad & Tobago", "Country"] = "Trinidad and Tobago"

# %%
second[second["Country"].isin(third["Country"]) == False]
# Out:
#      Happiness Rank            Country                       Region  \
# 14               15        Puerto Rico  Latin America and Caribbean
# 39               40           Suriname  Latin America and Caribbean
# 96               97  Somaliland Region           Sub-Saharan Africa
# 101             102               Laos            Southeastern Asia
# 137             138            Comoros           Sub-Saharan Africa
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 14             7.039                   1.35943  1.08113
# 39             6.269                   1.09686  0.77866
# 96             5.057                   0.25558  0.75862
# 101            4.876                   0.68042  0.54970
# 137            3.956                   0.27509  0.60323
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)
# 14                    0.77758  0.46823                        0.12275
# 39                    0.50933  0.52234                        0.12692
# ...

# %%
third[third["Country"].isin(second["Country"]) == False]
# Out:
#      Happiness Rank                   Country  Region  Happiness Score  \
# 112             113                Mozambique     NaN            4.550
# 138             139                   Lesotho     NaN            3.808
# 154             155  Central African Republic     NaN            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 112                  0.234306  0.870701                  0.106654  0.480791
# 138                  0.521021  1.190095                  0.000000  0.390661
# 154                  0.000000  0.000000                  0.018773  0.270842
#
#      Trust (Government Corruption)
# 112                       0.179436
# 138                       0.119095
# 154                       0.056565

# %%
third[third["Country"].isin(fourth["Country"]) == False]
# Out:
# Empty DataFrame
# Columns: [Happiness Rank, Country, Region, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption)]
# Index: []

# %%
fourth[fourth["Country"].isin(third["Country"]) == False]
# Out:
#      Happiness Rank Country  Region  Happiness Score  \
# 109             110    Laos     NaN            4.623
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 109                      0.72   1.034                     0.441    0.626
#
#      Trust (Government Corruption)
# 109                          0.174

# %%
third[third["Country"].isin(fifth["Country"]) == False]
# Out:
#      Happiness Rank    Country  Region  Happiness Score  \
# 49               50     Belize     NaN            5.956
# 91               92  Macedonia     NaN            5.175
# 129             130      Sudan     NaN            4.139
# 139             140     Angola     NaN            3.795
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 49                   0.907975  1.081418                  0.450192  0.547509
# 91                   1.064578  1.207893                  0.644948  0.325906
# 129                  0.659517  1.214009                  0.290921  0.014996
# 139                  0.858428  1.104412                  0.049869  0.000000
#
#      Trust (Government Corruption)
# 49                        0.096581
# 91                        0.060278
# 129                       0.089848
# 139                       0.069720

# %%
fifth[fifth["Country"].isin(third["Country"]) == False]
# Out:
#      Happiness Rank          Country Region  Happiness Score  \
# 83               84  North Macedonia    N/A            5.274
# 104             105             Laos    N/A            4.796
# 119             120           Gambia    N/A            4.516
# 134             135        Swaziland    N/A            4.212
# 141             142          Comoros    N/A            3.973
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 83                      0.983   1.294                     0.838    0.345
# 104                     0.764   1.030                     0.551    0.547
# 119                     0.308   0.939                     0.428    0.382
# 134                     0.811   1.149                     0.000    0.313
# 141                     0.274   0.757                     0.505    0.142
#
#      Trust (Government Corruption)
# 83                           0.034
# 104                          0.164
# 119                          0.167
# ...

# %%
third.loc[third["Country"]=="Macedonia", "Country"] = "North Macedonia"

# %%
fourth[fourth["Country"].isin(fifth["Country"]) == False]
# Out:
#      Happiness Rank    Country  Region  Happiness Score  \
# 48               49     Belize     NaN            5.956
# 88               89  Macedonia     NaN            5.185
# 136             137      Sudan     NaN            4.139
# 141             142     Angola     NaN            3.795
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 48                      0.807   1.101                     0.474    0.593
# 88                      0.959   1.239                     0.691    0.394
# 136                     0.605   1.240                     0.312    0.016
# 141                     0.730   1.125                     0.269    0.000
#
#      Trust (Government Corruption)
# 48                           0.089
# 88                           0.052
# 136                          0.082
# 141                          0.061

# %%
fifth[fifth["Country"].isin(fourth["Country"]) == False]
# Out:
#      Happiness Rank          Country Region  Happiness Score  \
# 83               84  North Macedonia    N/A            5.274
# 119             120           Gambia    N/A            4.516
# 134             135        Swaziland    N/A            4.212
# 141             142          Comoros    N/A            3.973
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 83                      0.983   1.294                     0.838    0.345
# 119                     0.308   0.939                     0.428    0.382
# 134                     0.811   1.149                     0.000    0.313
# 141                     0.274   0.757                     0.505    0.142
#
#      Trust (Government Corruption)
# 83                           0.034
# 119                          0.167
# 134                          0.135
# 141                          0.078

# %%
fourth.loc[fourth["Country"]=="Macedonia", "Country"] = "North Macedonia"

# %%
grouped = pd.concat([first["Country"], first["Region"],
                    first["Happiness Score"], first["Happiness Rank"], 
                    second["Happiness Score"], second["Happiness Rank"], 
                    third["Happiness Score"], third["Happiness Rank"], 
                    fourth["Happiness Score"], fourth["Happiness Rank"], 
                    fifth["Happiness Score"], fifth["Happiness Rank"]],
                    axis=1, 
                    keys=["Country", "Region", 
                          "Happiness Score 2015", "Happiness Rank 2015",
                          "Happiness Score 2016", "Happiness Rank 2016",
                          "Happiness Score 2017", "Happiness Rank 2017", 
                          "Happiness Score 2018", "Happiness Rank 2018", 
                          "Happiness Score 2019", "Happiness Rank 2019"]
                   )

# %%
grouped.head()
# Out:
#        Country          Region  Happiness Score 2015  Happiness Rank 2015  \
# 0  Switzerland  Western Europe                 7.587                    1
# 1      Iceland  Western Europe                 7.561                    2
# 2      Denmark  Western Europe                 7.527                    3
# 3       Norway  Western Europe                 7.522                    4
# 4       Canada   North America                 7.427                    5
#
#    Happiness Score 2016  Happiness Rank 2016  Happiness Score 2017  \
# 0                 7.526                  1.0                 7.537
# 1                 7.509                  2.0                 7.522
# 2                 7.501                  3.0                 7.504
# 3                 7.498                  4.0                 7.494
# 4                 7.413                  5.0                 7.469
#
#    Happiness Rank 2017  Happiness Score 2018  Happiness Rank 2018  \
# ...

# %%
grouped[pd.isnull(grouped).any(axis=1)]
grouped.dropna()
# Out:
#           Country              Region  Happiness Score 2015  \
# 0     Switzerland      Western Europe                 7.587
# 1         Iceland      Western Europe                 7.561
# 2         Denmark      Western Europe                 7.527
# 3          Norway      Western Europe                 7.522
# 4          Canada       North America                 7.427
# ..            ...                 ...                   ...
# 150   Ivory Coast  Sub-Saharan Africa                 3.655
# 151  Burkina Faso  Sub-Saharan Africa                 3.587
# 152   Afghanistan       Southern Asia                 3.575
# 153        Rwanda  Sub-Saharan Africa                 3.465
# 154         Benin  Sub-Saharan Africa                 3.340
#
#      Happiness Rank 2015  Happiness Score 2016  Happiness Rank 2016  \
# 0                      1                 7.526                  1.0
# 1                      2                 7.509                  2.0
# ...

# %%
grouped["Rank Change"] = grouped["Happiness Rank 2019"] - grouped["Happiness Rank 2015"]
grouped["Score Change"] = grouped["Happiness Score 2019"] - grouped["Happiness Score 2015"]

# %%
sorted_by_rankChange = grouped.sort_values(by=["Rank Change"], ascending=True)
sorted_by_rankChange.head()
# Out:
#          Country                           Region  Happiness Score 2015  \
# 0    Switzerland                   Western Europe                 7.587
# 100    Swaziland               Sub-Saharan Africa                 4.867
# 101       Greece                   Western Europe                 4.857
# 102      Lebanon  Middle East and Northern Africa                 4.839
# 103      Hungary       Central and Eastern Europe                 4.800
#
#      Happiness Rank 2015  Happiness Score 2016  Happiness Rank 2016  \
# 0                      1                 7.526                  1.0
# 100                  101                 4.907                101.0
# 101                  102                 4.876                102.0
# 102                  103                 4.875                103.0
# 103                  104                 4.871                104.0
#
#      Happiness Score 2017  Happiness Rank 2017  Happiness Score 2018  \
# ...

# %%
sorted_by_rankChange.sort_values(by=["Rank Change"], ascending=False).head()
# Out:
#        Country                           Region  Happiness Score 2015  \
# 82  Montenegro       Central and Eastern Europe                 5.192
# 10      Israel  Middle East and Northern Africa                 7.278
# 3       Norway                   Western Europe                 7.522
# 4       Canada                    North America                 7.427
# 5      Finland                   Western Europe                 7.406
#
#     Happiness Rank 2015  Happiness Score 2016  Happiness Rank 2016  \
# 82                   82                 5.245                 83.0
# 10                   11                 7.267                 11.0
# 3                     4                 7.498                  4.0
# 4                     5                 7.413                  5.0
# 5                     6                 7.404                  6.0
#
#     Happiness Score 2017  Happiness Rank 2017  Happiness Score 2018  \
# 82                 5.237                 83.0                 5.302
# ...

# %%
sorted_by_scoreChange = grouped.sort_values(by=["Score Change"], ascending=True)
sorted_by_scoreChange.head()
# Out:
#          Country                       Region  Happiness Score 2015  \
# 152  Afghanistan                Southern Asia                 3.575
# 24        Panama  Latin America and Caribbean                 6.786
# 25       Germany               Western Europe                 6.750
# 150  Ivory Coast           Sub-Saharan Africa                 3.655
# 153       Rwanda           Sub-Saharan Africa                 3.465
#
#      Happiness Rank 2015  Happiness Score 2016  Happiness Rank 2016  \
# 152                  153                 3.484                153.0
# 24                    25                 6.701                 25.0
# 25                    26                 6.650                 26.0
# 150                  151                 3.607                151.0
# 153                  154                 3.360                154.0
#
#      Happiness Score 2017  Happiness Rank 2017  Happiness Score 2018  \
# 152                 3.349                153.0                 3.303
# ...

# %%
sorted_by_scoreChange.sort_values(by=["Score Change"], ascending=False).head()
# Out:
#               Country                           Region  Happiness Score 2015  \
# 93         Mozambique               Sub-Saharan Africa                 4.971
# 92    North Macedonia       Central and Eastern Europe                 5.007
# 0         Switzerland                   Western Europe                 7.587
# 91            Morocco  Middle East and Northern Africa                 5.013
# 90  Somaliland Region               Sub-Saharan Africa                 5.057
#
#     Happiness Rank 2015  Happiness Score 2016  Happiness Rank 2016  \
# 93                   94                 5.123                 94.0
# 92                   93                 5.129                 93.0
# 0                     1                 7.526                  1.0
# 91                   92                 5.132                 92.0
# 90                   91                 5.145                 91.0
#
#     Happiness Score 2017  Happiness Rank 2017  Happiness Score 2018  \
# ...

# %%
grouped_region = grouped.groupby(["Region"])[["Happiness Score 2015", "Happiness Score 2016", 
                                    "Happiness Score 2017", "Happiness Score 2018", "Happiness Score 2019"]]

# %%
grouped_region.groups.keys()
# Out:
# dict_keys(['Australia and New Zealand', 'Central and Eastern Europe', 'Eastern Asia', 'Latin America and Caribbean', 'Middle East and Northern Africa', 'North America', 'Southeastern Asia', 'Southern Asia', 'Sub-Saharan Africa', 'Western Europe'])

# %%
from matplotlib.ticker import FormatStrFormatter

fig, axs = plt.subplots(3,2, figsize=(15,15))
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.6)

axs[0,0].bar(grouped_region.groups.keys(), grouped_region.mean()["Happiness Score 2015"])
axs[0,0].tick_params(axis='x', rotation=70)
axs[0,0].set_xlabel("Region")
axs[0,0].set_ylabel("Score")
axs[0,0].set_title("Happiness Score 2015")

axs[0,1].bar(grouped_region.groups.keys(), grouped_region.mean()["Happiness Score 2016"])
axs[0,1].tick_params(axis='x', rotation=70)
axs[0,1].set_xlabel("Region")
axs[0,1].set_ylabel("Score")
axs[0,1].set_title("Happiness Score 2016")

axs[1,0].bar(grouped_region.groups.keys(), grouped_region.mean()["Happiness Score 2017"])
axs[1,0].tick_params(axis='x', rotation=70)
axs[1,0].set_xlabel("Region")
axs[1,0].set_ylabel("Score")
axs[1,0].set_title("Happiness Score 2017")

axs[1,1].bar(grouped_region.groups.keys(), grouped_region.mean()["Happiness Score 2018"])
axs[1,1].tick_params(axis='x', rotation=70)
axs[1,1].set_xlabel("Region")
axs[1,1].set_ylabel("Score")
axs[1,1].set_title("Happiness Score 2018")

axs[2,0].bar(grouped_region.groups.keys(), grouped_region.mean()["Happiness Score 2019"])
axs[2,0].tick_params(axis='x', rotation=70)
axs[2,0].set_xlabel("Region")
axs[2,0].set_ylabel("Score")
axs[2,0].set_title("Happiness Score 2019")

plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(18, 10))
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.6)


sns.barplot(ax=axs[0, 0], data=first.head(10), x="Country", y="Happiness Score")
sns.barplot(ax=axs[0, 1], data=second.head(10), x="Country", y="Happiness Score")
sns.barplot(ax=axs[1, 0], data=third.head(10), x="Country", y="Happiness Score")
sns.barplot(ax=axs[1, 1], data=fourth.head(10), x="Country", y="Happiness Score")
sns.barplot(ax=axs[2, 0], data=fifth.head(10), x="Country", y="Happiness Score")

axs[0,0].tick_params(axis='x', rotation=15)
axs[0,0].set_title("2015")

axs[0,1].tick_params(axis='x', rotation=15)
axs[0,1].set_title("2016")

axs[1,0].tick_params(axis='x', rotation=15)
axs[1,0].set_title("2017")

axs[1,1].tick_params(axis='x', rotation=15)
axs[1,1].set_title("2018")

axs[2,0].tick_params(axis='x', rotation=15)
axs[2,0].set_title("2019")



plt.show()

# %%
dataframe_mean = pd.concat([first, second, third, fourth, fifth]).groupby("Country", as_index=False).mean()

# %%
dataframe_mean.sort_values(by="Happiness Score", ascending=False, inplace=True)
dataframe_mean.index = np.arange(1, len(dataframe_mean)+1)

# %%
dataframe_mean.head(10)
# Out:
#         Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 1       Denmark             2.2           7.5460                  1.396729
# 2        Norway             2.8           7.5410                  1.519381
# 3       Finland             3.6           7.5378                  1.356960
# 4   Switzerland             3.6           7.5114                  1.472164
# 5       Iceland             3.2           7.5110                  1.386523
# 6   Netherlands             6.2           7.4046                  1.411013
# 7        Canada             6.8           7.3506                  1.388129
# 8        Sweden             8.6           7.3192                  1.403981
# 9   New Zealand             8.2           7.3130                  1.317509
# 10    Australia            10.0           7.2762                  1.394885
#
#       Family  Health (Life Expectancy)   Freedom  \
# 1   1.447688                  0.865249  0.625959
# ...

# %%
fig, axs = plt.subplots(3, 2, figsize=(18, 12))
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.6)

sns.barplot(ax=axs[0, 0], data=dataframe_mean.head(10), x="Country", y="Happiness Score")
sns.barplot(ax=axs[0, 1], data=dataframe_mean.sort_values(by="Economy (GDP per Capita)", ascending=False).head(10), x="Country", y="Economy (GDP per Capita)")
sns.barplot(ax=axs[1, 0], data=dataframe_mean.sort_values(by="Family", ascending=False).head(10), x="Country", y="Family")
sns.barplot(ax=axs[1, 1], data=dataframe_mean.sort_values(by="Health (Life Expectancy)", ascending=False).head(10), x="Country", y="Health (Life Expectancy)")
sns.barplot(ax=axs[2, 0], data=dataframe_mean.sort_values(by="Freedom", ascending=False).head(10), x="Country", y="Freedom")
sns.barplot(ax=axs[2, 1], data=dataframe_mean.sort_values(by="Trust (Government Corruption)", ascending=False).head(10), x="Country", y="Trust (Government Corruption)")


axs[0,0].tick_params(axis='x', rotation=15)
axs[0,0].set_title("Highest Happines Score")

axs[0,1].tick_params(axis='x', rotation=15)
axs[0,1].set_title("Highest Economies")

axs[1,0].tick_params(axis='x', rotation=15)
axs[1,0].set_title("Family")

axs[1,1].tick_params(axis='x', rotation=15)
axs[1,1].set_title("Highest Life Expectancy")

axs[2,0].tick_params(axis='x', rotation=15)
axs[2,0].set_title("Highest Freedom")

axs[2,1].tick_params(axis='x', rotation=15)
axs[2,1].set_title("Highest Trust")
# Out:
# Text(0.5, 1.0, 'Highest Trust')

# %%
dataframe_mean.loc[dataframe_mean["Country"]=="Turkey"]
# Out:
#    Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 78  Turkey            75.2           5.4154                  1.151035
#
#       Family  Health (Life Expectancy)   Freedom  \
# 78  1.180249                  0.702101  0.257356
#
#     Trust (Government Corruption)
# 78                       0.119122

# %%
dataframe_mean.iloc[72:83]
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 73         Libya            68.0           5.5970                  1.065827
# 74  Turkmenistan            69.8           5.5822                  1.047483
# 75     Venezuela            71.8           5.5314                  1.052468
# 76       Croatia            74.0           5.4586                  1.152317
# 77     Hong Kong            74.0           5.4528                  1.458283
# 78        Turkey            75.2           5.4154                  1.151035
# 79   Philippines            76.8           5.3874                  0.791438
# 80      Pakistan            79.0           5.3440                  0.667895
# 81        Serbia            78.8           5.3392                  1.000644
# 82       Hungary            80.2           5.3294                  1.204074
# 83      Portugal            82.8           5.3046                  1.232031
#
#       Family  Health (Life Expectancy)   Freedom  \
# ...
